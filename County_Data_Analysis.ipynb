# %%
#dependencies
import pandas as pd
state_data = "Resources/StateData.csv"
geocodes_data = "Resources/Geocodes_USA_with_Counties.csv"
CHR_data = "Resources/CHR_Data.csv"
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sem
from scipy.stats import linregress
import numpy as np
from sklearn import datasets

# %%
# import cleaned study data from csv
county_health_df = "Resources/FullData.csv"
county_health_df = pd.read_csv(county_health_df)
county_health_df.head()
# Out:
#    Unnamed: 0  FIPS    State   County  Years of Potential Life Lost Rate  \
# 0           0  1001  Alabama  Autauga                             8129.0
# 1           1  1003  Alabama  Baldwin                             7354.0
# 2           2  1005  Alabama  Barbour                            10254.0
# 3           3  1007  Alabama     Bibb                            11978.0
# 4           4  1009  Alabama   Blount                            11335.0
#
#    % Fair or Poor Health  Average Number of Physically Unhealthy Days  \
# 0                     21                                          4.7
# 1                     18                                          4.2
# 2                     30                                          5.4
# 3                     19                                          4.6
# 4                     22                                          4.9
#
#    Average Number of Mentally Unhealthy Days  % Adults with Obesity  \
# 0                                        4.7                     33
# 1                                        4.3                     31
# 2                                        5.2                     42
# 3                                        4.6                     38
# 4                                        4.9                     34
#
#    Food Environment Index  ...  Primary Care Physicians Ratio  \
# 0                     7.2  ...                     2220:01:00
# 1                     8.0  ...                     1372:01:00
# 2                     5.6  ...                     3159:01:00
# 3                     7.8  ...                     2061:01:00
# 4                     8.4  ...                     4463:01:00
#
#    Preventable Hospitalization Rate Population  % Unemployed  Income Ratio  \
# 0                            7108.0      14438           3.6           5.2
# 1                            4041.0      48703           3.6           4.4
# 2                            6209.0       6779           5.2           5.7
# 3                            5961.0       5970           4.0           4.4
# 4                            4060.0      13939           3.5           4.4
#
#    Social Association Rate  Code      zip    Lat    Lon
# 0                     12.1    AL  36003.0  32.43 -86.65
# 1                     10.2    AL  36507.0  30.88 -87.77
# 2                      7.5    AL  36016.0  31.88 -85.45
# 3                      8.4    AL  35034.0  32.94 -87.17
# 4                      8.4    AL  35013.0  33.90 -86.51
#
# [5 rows x 22 columns]

# %%
#Create variables to graph
prev_hosp = county_health_df["Preventable Hospitalization Rate"]
food_index = county_health_df["Food Environment Index"]
years_ll = county_health_df["Years of Potential Life Lost Rate"]
obesity = county_health_df["% Adults with Obesity"]
unempl = county_health_df["% Unemployed"]
income_ratio = county_health_df["Income Ratio"]
fair_health = county_health_df['% Fair or Poor Health']
ph_unhealthy = county_health_df['Average Number of Physically Unhealthy Days']
mh_unhealthy = county_health_df['Average Number of Mentally Unhealthy Days']
pcp_ratio = county_health_df['Primary Care Physicians Ratio']
pop = county_health_df['Population']
social = county_health_df['Social Association Rate']

# %%
# assess relationship of variables between two outcomes: preventable hosp and poor health
x_values = prev_hosp
y_values = fair_health

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('prev_hosp')
plt.ylabel('fair_health')
plt.title(f"prev_hosp and fair_health")
plt.show()
# Out:
# The r-squared is: 0.22257888580567142

# %%
x_values = prev_hosp
y_values = food_index

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('prev_hosp')
plt.ylabel('food_index')
plt.title(f"prev_hosp and food_index")
plt.show()
# Out:
# The r-squared is: 0.0612851141839349

# %%
x_values = prev_hosp
y_values = obesity

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('prev_hosp')
plt.ylabel('obesity')
plt.title(f"prev_hosp and obesity")
plt.show()
# Out:
# The r-squared is: 0.11608996797242234

# %%
x_values = prev_hosp
y_values = income_ratio

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('prev_hosp')
plt.ylabel('income_ratio')
plt.title(f"prev_hosp and income_ratio")
plt.show()
# Out:
# The r-squared is: 0.08040404405638894

# %%
# Assess relationship between fair or poor health and variables
x_values = prev_hosp
y_values = fair_health

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('prev_hosp')
plt.ylabel('fair_health')
plt.title(f"prev_hosp and fair_health")
plt.show()

# %%
# pick top and bottom counties of fair or poor health outcomes and create study dataframe

n_cities=20

top_n = county_health_df.nlargest(n_cities, ['% Fair or Poor Health'])
bottom_n = county_health_df.nsmallest(n_cities, ['% Fair or Poor Health'])
study_df = pd.concat([top_n,bottom_n])

study_df = study_df.reset_index(drop=True)
study_df
# Out:
#     Unnamed: 0   FIPS          State       County  \
# 0         2403  48507          Texas       Zavala
# 1         2368  48427          Texas        Starr
# 2         1281  28051    Mississippi       Holmes
# 3         1268  28021    Mississippi    Claiborne
# 4         1286  28063    Mississippi    Jefferson
# 5         2394  48489          Texas      Willacy
# 6         1282  28053    Mississippi    Humphreys
# 7         1313  28119    Mississippi      Quitman
# 8         2402  48505          Texas       Zapata
# 9           50   1105        Alabama        Perry
# 10        1271  28027    Mississippi      Coahoma
# 11        2327  48323          Texas     Maverick
# 12        2350  48377          Texas     Presidio
# 13        2389  48479          Texas         Webb
# 14          30   1063        Alabama       Greene
# 15          57   1119        Alabama       Sumter
# 16         942  21147       Kentucky     McCreary
# 17        2253  48127          Texas       Dimmit
# 18         144   5107       Arkansas     Phillips
# 19         463  13259        Georgia      Stewart
# 20         233   8035       Colorado      Douglas
# 21         242   8059       Colorado    Jefferson
# 22         835  20091         Kansas      Johnson
# 23        1050  23005          Maine   Cumberland
# 24        1190  27019      Minnesota       Carver
# 25        1254  27163      Minnesota   Washington
# 26        1543  33015  New Hampshire   Rockingham
# 27        2098  46083   South Dakota      Lincoln
# 28         227   8014       Colorado   Broomfield
# 29         229   8019       Colorado  Clear Creek
# 30         265   8119       Colorado       Teller
# 31         272   9007    Connecticut    Middlesex
# 32         275   9013    Connecticut      Tolland
# 33        1076  24027       Maryland       Howard
# 34        1088  25001  Massachusetts   Barnstable
# 35        1198  27037      Minnesota       Dakota
# 36        1206  27053      Minnesota     Hennepin
# 37        1229  27109      Minnesota      Olmsted
# 38        1578  35028     New Mexico   Los Alamos
# 39        2093  46057   South Dakota       Hamlin
#
#     Years of Potential Life Lost Rate  % Fair or Poor Health  \
# 0                              8926.0                     41
# 1                              6697.0                     39
# 2                             14318.0                     38
# 3                             14651.0                     37
# 4                             15171.0                     37
# 5                              8421.0                     37
# 6                             10771.0                     36
# 7                             13903.0                     36
# 8                              7996.0                     36
# 9                             14264.0                     35
# 10                            15128.0                     35
# 11                             6970.0                     35
# 12                             5107.0                     35
# 13                             6027.0                     35
# 14                            11619.0                     34
# 15                            13159.0                     34
# 16                            13013.0                     34
# 17                             7766.0                     34
# 18                            14528.0                     33
# 19                            12236.0                     33
# 20                             3549.0                      8
# 21                             5397.0                      9
# 22                             4252.0                      9
# 23                             5626.0                      9
# 24                             3593.0                      9
# 25                             4338.0                      9
# 26                             5588.0                      9
# 27                             4479.0                      9
# 28                             4551.0                     10
# 29                             5065.0                     10
# 30                             7155.0                     10
# 31                             5466.0                     10
# 32                             5008.0                     10
# 33                             4160.0                     10
# 34                             7303.0                     10
# 35                             4288.0                     10
# 36                             5091.0                     10
# 37                             4420.0                     10
# 38                             4614.0                     10
# 39                             5128.0                     10
#
#     Average Number of Physically Unhealthy Days  \
# 0                                           5.7
# 1                                           5.5
# 2                                           6.1
# 3                                           6.1
# 4                                           6.2
# 5                                           5.3
# 6                                           5.9
# 7                                           6.0
# 8                                           5.1
# 9                                           6.4
# 10                                          5.8
# 11                                          5.0
# 12                                          5.1
# 13                                          5.1
# 14                                          5.9
# 15                                          5.9
# 16                                          6.4
# 17                                          5.0
# 18                                          5.6
# 19                                          5.0
# 20                                          2.5
# 21                                          2.7
# 22                                          2.5
# 23                                          3.0
# 24                                          2.4
# 25                                          2.7
# 26                                          2.9
# 27                                          2.5
# 28                                          3.0
# 29                                          2.9
# 30                                          3.1
# 31                                          3.0
# 32                                          3.1
# 33                                          2.6
# 34                                          3.2
# 35                                          2.9
# 36                                          2.6
# 37                                          2.7
# 38                                          3.1
# 39                                          2.6
#
#     Average Number of Mentally Unhealthy Days  % Adults with Obesity  \
# 0                                         4.9                     24
# 1                                         4.8                     38
# 2                                         5.6                     46
# 3                                         5.5                     41
# 4                                         5.5                     54
# 5                                         4.5                     40
# 6                                         5.6                     46
# 7                                         5.5                     42
# 8                                         4.5                     31
# 9                                         5.9                     43
# 10                                        5.4                     42
# 11                                        4.4                     38
# 12                                        4.6                     30
# 13                                        4.5                     38
# 14                                        5.5                     36
# 15                                        5.4                     43
# 16                                        5.9                     40
# 17                                        4.5                     33
# 18                                        5.3                     43
# 19                                        4.4                     32
# 20                                        2.9                     20
# 21                                        3.4                     21
# 22                                        2.9                     27
# 23                                        3.8                     23
# 24                                        2.8                     24
# 25                                        2.7                     25
# 26                                        3.6                     27
# 27                                        2.5                     30
# 28                                        3.4                     20
# 29                                        3.3                     22
# 30                                        3.5                     21
# 31                                        3.6                     26
# 32                                        3.3                     25
# 33                                        3.1                     25
# 34                                        3.9                     21
# 35                                        2.9                     29
# 36                                        3.0                     23
# 37                                        3.3                     27
# 38                                        3.5                     23
# 39                                        2.6                     29
#
#     Food Environment Index  ...  Primary Care Physicians Ratio  \
# 0                      6.2  ...                     5974:01:00
# 1                      5.4  ...                     4958:01:00
# 2                      1.5  ...                     1971:01:00
# 3                      3.5  ...                     2238:01:00
# 4                      3.3  ...                     1816:01:00
# 5                      7.3  ...                     2698:01:00
# 6                      3.8  ...                     2781:01:00
# 7                      3.2  ...                     7269:01:00
# 8                      6.2  ...                        14322:1
# 9                      4.9  ...                     3113:01:00
# 10                     3.6  ...                     1781:01:00
# 11                     6.8  ...                     3881:01:00
# 12                     4.4  ...                     3578:01:00
# 13                     7.8  ...                     3088:01:00
# 14                     3.2  ...                     2083:01:00
# 15                     4.6  ...                     1812:01:00
# 16                     6.6  ...                     4366:01:00
# 17                     7.2  ...                     2605:01:00
# 18                     2.4  ...                     1857:01:00
# 19                     6.1  ...                     2993:01:00
# 20                     9.2  ...                     1427:01:00
# 21                     8.6  ...                     1170:01:00
# 22                     8.6  ...                      815:01:00
# 23                     8.0  ...                      602:01:00
# 24                     9.5  ...                     1201:01:00
# 25                     8.9  ...                      925:01:00
# 26                     8.9  ...                     1321:01:00
# 27                     9.3  ...                      637:01:00
# 28                     8.6  ...                      949:01:00
# 29                     8.7  ...                     9574:01:00
# 30                     8.7  ...                     2054:01:00
# 31                     8.5  ...                     1409:01:00
# 32                     8.2  ...                     1993:01:00
# 33                     9.3  ...                      517:01:00
# 34                     8.4  ...                     1026:01:00
# 35                     8.9  ...                     1512:01:00
# 36                     8.3  ...                      849:01:00
# 37                     8.9  ...                      440:01:00
# 38                     7.9  ...                      669:01:00
# 39                     6.2  ...                     5948:01:00
#
#     Preventable Hospitalization Rate Population  % Unemployed  Income Ratio  \
# 0                             5987.0       2899           9.5           5.1
# 1                             6903.0      15932          10.1           5.4
# 2                             4789.0       4214           8.9           6.6
# 3                            11397.0       1829           9.2           5.5
# 4                             9523.0       1789          13.3           5.1
# 5                             5558.0       6278           9.9           6.1
# 6                             5107.0       1861           8.4           5.1
# 7                             6679.0       1722           7.6           6.1
# 8                             5154.0       3454           5.6           5.4
# 9                             5342.0       1929           6.5           4.7
# 10                            6499.0       5490           6.8           6.1
# 11                            7677.0      14401           8.1           5.6
# 12                            4009.0       1436           7.0           5.5
# 13                            5162.0      72025           3.8           5.9
# 14                            7121.0       1772           6.7           5.9
# 15                            5643.0       2371           5.9           7.6
# 16                            7302.0       4869           6.3           5.2
# 17                            5322.0       2801           3.0           6.2
# 18                            7250.0       4087           6.1           6.0
# 19                            5923.0       2251           4.7           6.4
# 20                            3171.0      85839           2.9           3.3
# 21                            2427.0     157065           3.0           4.0
# 22                            3919.0     161930           2.9           4.0
# 23                            2537.0      74202           2.7           4.4
# 24                            7697.0      25305           2.5           3.9
# 25                            5573.0      62523           2.5           3.6
# 26                            3961.0      71025           2.8           3.9
# 27                            5933.0      16402           2.3           3.6
# 28                            1582.0      19680           2.9           3.8
# 29                             942.0       2166           3.0           3.6
# 30                            3628.0       4606           3.7           4.1
# 31                            4402.0      36131           3.5           4.5
# 32                            4029.0      31630           3.6           4.3
# 33                            3193.0      82744           3.0           3.7
# 34                            2983.0      37749           4.3           4.4
# 35                            5740.0     110392           2.5           3.8
# 36                            5751.0     374964           2.5           4.9
# 37                            3966.0      42071           2.3           4.2
# 38                            1659.0       4331           3.4           3.6
# 39                            6208.0       1292           3.1           2.6
#
#     Social Association Rate  Code      zip    Lat     Lon
# 0                       3.3    TX  78829.0  28.94  -99.61
# 1                       2.3    TX  78536.0  26.64  -98.40
# 2                      10.1    MS  38924.0  33.32  -90.23
# 3                       4.5    MS  39086.0  32.02  -90.80
# 4                       4.1    MS  39069.0  31.71  -91.06
# 5                       5.1    TX  78561.0  26.53  -97.88
# 6                      10.8    MS  38754.0  33.26  -90.59
# 7                       9.6    MS  38609.0  34.26  -90.35
# 8                       2.1    TX  78067.0  27.19  -99.32
# 9                      10.7    AL  36756.0  32.63  -87.31
# 10                      7.8    MS  38614.0  34.20  -90.57
# 11                      2.6    TX  78852.0  28.70 -100.49
# 12                      8.4    TX  79843.0  30.31 -104.02
# 13                      3.4    TX  78040.0  27.53  -99.48
# 14                      9.6    AL  35443.0  32.75  -88.02
# 15                      9.5    AL  35459.0  32.72  -88.31
# 16                      3.4    KY  42631.0  36.74  -84.48
# 17                      6.7    TX  78827.0  28.44  -99.76
# 18                     11.3    AR  72312.0  34.59  -90.79
# 19                      6.7    GA  31814.0  32.16  -84.81
# 20                      6.1    CO  80104.0  39.37 -104.85
# 21                      7.8    CO  80001.0  39.82 -105.10
# 22                      8.6    KS  66013.0  38.71  -94.71
# 23                     13.2    ME   4003.0  43.73  -69.99
# 24                     10.4    MN  55315.0  44.76  -93.62
# 25                      8.7    MN  55001.0  44.90  -92.81
# 26                      9.6    NH   3032.0  43.00  -71.34
# 27                     12.5    SD  57013.0  43.30  -96.58
# 28                      6.3    CO  80020.0  39.94 -105.06
# 29                      4.2    CO  80436.0  39.78 -105.60
# 30                      9.7    CO  80813.0  38.74 -105.17
# 31                     10.5    CT   6409.0  41.34  -72.41
# 32                      7.1    CT   6029.0  41.90  -72.46
# 33                      8.8    MD  20588.0  38.74  -76.85
# 34                     12.7    MA   2532.0  41.75  -70.61
# 35                      8.7    MN  55010.0  44.58  -93.09
# 36                     11.0    MN  55111.0  44.94  -93.10
# 37                     12.0    MN  55901.0  44.01  -92.47
# 38                     17.1    NM  87544.0  35.89 -106.28
# 39                      8.4    SD  57221.0  44.58  -97.46
#
# [40 rows x 22 columns]

# %%
study_df.to_csv("Resources/PoorHealth_StudyData.csv")
