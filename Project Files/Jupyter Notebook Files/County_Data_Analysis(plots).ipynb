# %%
#dependencies
import pandas as pd

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sem
from scipy.stats import linregress
import numpy as np
from sklearn import datasets

# %%
# import cleaned study data from csv
county_health_df = "Resources/FullData.csv"
county_health_df = pd.read_csv(county_health_df)
county_health_df.head()
# Out:
#    Unnamed: 0  FIPS    State   County  Years of Potential Life Lost Rate  \
# 0           0  1001  Alabama  Autauga                             8129.0
# 1           1  1003  Alabama  Baldwin                             7354.0
# 2           2  1005  Alabama  Barbour                            10254.0
# 3           3  1007  Alabama     Bibb                            11978.0
# 4           4  1009  Alabama   Blount                            11335.0
#
#    % Fair or Poor Health  Average Number of Physically Unhealthy Days  \
# 0                     21                                          4.7
# 1                     18                                          4.2
# 2                     30                                          5.4
# 3                     19                                          4.6
# 4                     22                                          4.9
#
#    Average Number of Mentally Unhealthy Days  % Adults with Obesity  \
# ...

# %%
#Create variables to graph
prev_hosp = county_health_df["Preventable Hospitalization Rate"]
food_index = county_health_df["Food Environment Index"]
years_ll = county_health_df["Years of Potential Life Lost Rate"]
obesity = county_health_df["% Adults with Obesity"]
unempl = county_health_df["% Unemployed"]
income_ratio = county_health_df["Income Ratio"]
fair_health = county_health_df['% Fair or Poor Health']
ph_unhealthy = county_health_df['Average Number of Physically Unhealthy Days']
mh_unhealthy = county_health_df['Average Number of Mentally Unhealthy Days']
pcp_ratio = county_health_df['Primary Care Physicians Ratio']
pop = county_health_df['Population']
social = county_health_df['Social Association Rate']
smokers = county_health_df['% Smokers']
drinking = county_health_df['% Excessive Drinking']
grad = county_health_df['High School Graduation Rate']

# %%
# assess relationship of variables between two outcomes: preventable hosp and poor health
x_values = prev_hosp
y_values = fair_health

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('prev_hosp')
plt.ylabel('fair_health')
plt.title(f"prev_hosp and fair_health")
plt.savefig("Prev Hosp & Fair Health.png")
plt.show()
# Out:
# The r-squared is: 0.2255893484029814

# %%
x_values = prev_hosp
y_values = food_index

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('prev_hosp')
plt.ylabel('food_index')
plt.title(f"prev_hosp and food_index")
plt.savefig("Prev Hosp & Food Index.png")
plt.show()
# Out:
# The r-squared is: 0.06571437574462385

# %%
x_values = prev_hosp
y_values = obesity

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('prev_hosp')
plt.ylabel('obesity')
plt.title(f"prev_hosp and obesity")
plt.savefig("Prev Hosp & Obesity.png")
plt.show()
# Out:
# The r-squared is: 0.11995959628855725

# %%
x_values = prev_hosp
y_values = income_ratio

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('prev_hosp')
plt.ylabel('income_ratio')
plt.title(f"prev_hosp and income_ratio")
plt.savefig("Prev Hosp & Income Ratio.png")
plt.show()
# Out:
# The r-squared is: 0.08038279827228219

# %%
# prev_hosp = county_health_df["Preventable Hospitalization Rate"]
# food_index = county_health_df["Food Environment Index"]
# years_ll = county_health_df["Years of Potential Life Lost Rate"]
# obesity = county_health_df["% Adults with Obesity"]
# unempl = county_health_df["% Unemployed"]
# income_ratio = county_health_df["Income Ratio"]
# fair_health = county_health_df['% Fair or Poor Health']
# ph_unhealthy = county_health_df['Average Number of Physically Unhealthy Days']
# mh_unhealthy = county_health_df['Average Number of Mentally Unhealthy Days']
# pcp = county_health_df['Primary Care Physicians Ratio']
# pop = county_health_df['Population']
# social = county_health_df['Social Association Rate']
# smokers = county_health_df['% Smokers']
# drinking = county_health_df['% Excessive Drinking']
# grad = county_health_df['High School Graduation Rate']

# %%
x_values = fair_health
y_values = social

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('fair_health')
plt.ylabel('social')
plt.title(f"fair_health and social")
plt.savefig("Fair Health & Social.png")
plt.show()
# Out:
# The r-squared is: 0.03996307900848683

# %%
x_values = fair_health
y_values = years_ll

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('fair_health')
plt.ylabel('years_ll')
plt.title(f"fair_health and years_ll")
plt.savefig("Fair Health & Years Lost.png")
plt.show()
# Out:
# The r-squared is: 0.4839648332256376

# %%
x_values = fair_health
y_values = ph_unhealthy

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('fair_health')
plt.ylabel('ph_unhealthy')
plt.title(f"fair_health and ph_unhealthy")
plt.savefig("Fair Health & Physically Unhealthy.png")
plt.show()
# Out:
# The r-squared is: 0.7792437161046455

# %%
x_values = fair_health
y_values = mh_unhealthy

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('fair_health')
plt.ylabel('mh_unhealthy')
plt.title(f"fair_health and mh_unhealthy")
plt.savefig("Fair Health & Mentally Unhealthy.png")
plt.show()
# Out:
# The r-squared is: 0.5941916138472672

# %%
x_values = fair_health
y_values = obesity

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('fair_health')
plt.ylabel('obesity')
plt.title(f"fair_health and obesity")
plt.savefig("Fair Health & Obesity.png")
plt.show()
# Out:
# The r-squared is: 0.1931922013517097

# %%
x_values = fair_health
y_values = smokers

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('fair_health')
plt.ylabel('smokers')
plt.title(f"fair_health and smokers")
plt.savefig("Fair Health & Smokers.png")
plt.show()
# Out:
# The r-squared is: 0.5177303472441445

# %%
x_values = fair_health
y_values = drinking

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('fair_health')
plt.ylabel('drinking')
plt.title(f"fair_health and drinking")
plt.savefig("Fair Health & Drinking.png")
plt.show()
# Out:
# The r-squared is: 0.4551326377465022

# %%
x_values = fair_health
y_values = grad

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('fair_health')
plt.ylabel('grad')
plt.title(f"fair_health and grad")
plt.savefig("Fair Health & Grad Rate.png")
plt.show()
# Out:
# The r-squared is: 0.007920877962894726

# %%
x_values = fair_health
y_values = unempl

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('fair_health')
plt.ylabel('unempl')
plt.title(f"fair_health and unempl")
plt.savefig("Fair Health & Unemployment.png")
plt.show()
# Out:
# The r-squared is: 0.26005540443176683

# %%
x_values = fair_health
y_values = income_ratio

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('fair_health')
plt.ylabel('income_ratio')
plt.title(f"fair_health and income_ratio")
plt.savefig("Fair Health & Income Ratio.png")
plt.show()
# Out:
# The r-squared is: 0.286196102947479

# %%
# Assess relationship between fair or poor health and variables
x_values = fair_health
y_values = food_index

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,5),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('fair_health')
plt.ylabel('food_index')
plt.title(f"fair_health and food_index")
plt.savefig("Fair Health & Food Index.png")
plt.show()
# Out:
# The r-squared is: 0.4258571568287756

# %%
# pick top and bottom counties of fair or poor health outcomes and create study dataframe

n_cities=20

top_n = county_health_df.nlargest(n_cities, ['% Fair or Poor Health'])
bottom_n = county_health_df.nsmallest(n_cities, ['% Fair or Poor Health'])
study_df = pd.concat([top_n,bottom_n])

study_df = study_df.reset_index(drop=True)
study_df
# Out:
#     Unnamed: 0   FIPS          State       County  \
# 0         2375  48507          Texas       Zavala
# 1         2340  48427          Texas        Starr
# 2         1276  28051    Mississippi       Holmes
# 3         1263  28021    Mississippi    Claiborne
# 4         1281  28063    Mississippi    Jefferson
# 5         2366  48489          Texas      Willacy
# 6         1277  28053    Mississippi    Humphreys
# 7         1308  28119    Mississippi      Quitman
# 8         2374  48505          Texas       Zapata
# 9           50   1105        Alabama        Perry
# 10        1266  28027    Mississippi      Coahoma
# 11        2299  48323          Texas     Maverick
# 12        2322  48377          Texas     Presidio
# 13        2361  48479          Texas         Webb
# 14          30   1063        Alabama       Greene
# 15          57   1119        Alabama       Sumter
# 16         941  21147       Kentucky     McCreary
# 17        2225  48127          Texas       Dimmit
# ...

# %%
study_df.to_csv("Resources/PoorHealth_StudyData.csv")

# %%
top_grouped = top_n.groupby(['State']).count()
county_count_top = top_grouped['County']
county_count_top
# Out:
# State
# Alabama        3
# Arkansas       1
# Georgia        1
# Kentucky       1
# Mississippi    6
# Texas          8
# Name: County, dtype: int64

# %%
labels = top_grouped.index
numbers = top_grouped['County']
county_count_top.plot(kind='pie', labels= numbers, title="Number of Counties with Highest % of Poor Health Population by State", fontsize=10)
plt.legend(loc = "center left", labels= labels,bbox_to_anchor=(1,0,.5,.6))
plt.axis("equal")
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)
plt.savefig("Counties with Highest % of Poor Health.png")
plt.show()

# %%
bottom_grouped = bottom_n.groupby(['State']).count()
county_count_bottom = bottom_grouped['County']
county_count_bottom
# Out:
# State
# Colorado         5
# Connecticut      2
# Kansas           1
# Maine            1
# Maryland         1
# Massachusetts    1
# Minnesota        5
# New Hampshire    1
# New Mexico       1
# South Dakota     2
# Name: County, dtype: int64

# %%
labels = bottom_grouped.index
numbers = bottom_grouped['County']
county_count_bottom.plot(kind='pie', labels= numbers, title="Number of Counties with Lowest % of Poor Health Population by State", fontsize=10)
plt.legend(loc = "center left", labels= labels,bbox_to_anchor=(1,0,.5,.6))
plt.axis("equal")
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)
plt.savefig("Counties with Lowest % of Poor Health.png")
plt.show()
