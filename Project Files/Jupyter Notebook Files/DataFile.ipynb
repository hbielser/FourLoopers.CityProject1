# %%
#dependencies
import requests
import json
import pandas as pd
import numpy as np
import gmaps


# Google developer API key
#from config import gkey
gkey = "AIzaSyAvuOCIVC1906HxDHTcVh8kpYL4QVPV2bQ"

# %%
county_geo = "../../Resources/StudyData.csv"
county_df = pd.read_csv(county_geo)
county_df.head()
# Out:
#    Unnamed: 0   FIPS          State      County  \
# 0           0  54059  West Virginia       Mingo
# 1           1  21171       Kentucky      Monroe
# 2           2  40057       Oklahoma      Harmon
# 3           3  54045  West Virginia       Logan
# 4           4  21055       Kentucky  Crittenden
#
#    Years of Potential Life Lost Rate  % Fair or Poor Health  \
# 0                            14564.0                     28
# 1                            12131.0                     24
# 2                            14123.0                     22
# 3                            15459.0                     26
# 4                            10623.0                     22
#
#    Average Number of Physically Unhealthy Days  \
# 0                                          6.3
# 1                                          5.2
# 2                                          4.4
# 3                                          5.8
# 4                                          5.0
#
#    Average Number of Mentally Unhealthy Days  % Adults with Obesity  \
# 0                                        6.1                     37
# 1                                        5.0                     37
# 2                                        4.4                     32
# 3                                        5.8                     42
# 4                                        5.0                     31
#
#    Food Environment Index  ...  Primary Care Physicians Ratio  \
# 0                     7.1  ...                     4825:01:00
# 1                     7.8  ...                     2132:01:00
# 2                     8.2  ...                     2689:01:00
# 3                     7.5  ...                     2058:01:00
# 4                     8.1  ...                     2271:01:00
#
#    Preventable Hospitalization Rate Population  % Unemployed  Income Ratio  \
# 0                           16802.0       5950           7.6           5.3
# 1                           15420.0       2458           4.1           5.8
# 2                           14776.0        704           2.9           4.9
# 3                           14383.0       8350           7.0           5.5
# 4                           13912.0       2101           5.2           4.7
#
#    Social Association Rate  Code      zip    Lat    Lon
# 0                      8.3    WV  24846.0  37.53 -81.85
# 1                      9.4    KY  42133.0  36.72 -85.96
# 2                     14.9    OK  73544.0  34.66 -99.77
# 3                      6.7    WV  25022.0  37.86 -81.83
# 4                     14.3    KY  42033.0  37.27 -88.08
#
# [5 rows x 22 columns]

# %%
#gkey = "AIzaSyDZ0NStSeomJLtlfN4UE3YMfDXWlBpi8A0"
# 39.0473° N, 95.6752° W
# 39.0375° N, 95.7680°
#base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#drugstore , gas_station,pharmacy
#params = {
    #"location": "39.0375,-95.7680",  
    #"rankby": "distance",
    #"type": "supermarket",
    #"key": gkey,
    #"radius": "50000"
#}
#food = []
#response = requests.get(base_url, params=params).json()
# extract results
#results = response['results']
#for r in results:
    #food.append(r)
    #params['page_token'] = response['next_page_token']
    #response = requests.get(base_url, params=params).json()
# extract results
    #results = response['results']
#for r in results:
    #food.append(r)
    #params['page_token'] = response['next_page_token']
    #response = requests.get(base_url, params=params).json()
# extract results
    #results = response['results']
#for r in results:
    #food.append(r)
    #token = response['next_page_token']
#print(food.__len__())
#csv_columns = ['name', 'opening_hours', 'price_level', 'id', 'scope', 'rating', 'types', 'plus_code',
               #'user_ratings_total', 'vicinity', 'place_id', 'business_status', 'geometry', 'photos', 'reference', 'icon']
#try:
    #with open("food.csv", 'w') as csvfile:
        #writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        #writer.writeheader()
        #for data in stores:
            #writer.writerow(data)
#except IOError:
 #   print("I/O error")

# %%
county_df["Restaurant Name"] = ""
county_df["Take Away Food"] = ""
county_df["Hospital"] = ""
county_df["Parks"]=""
county_df["Gyms"]=""
places_df = county_df[["State", "County", "Code", "Lat" , "Lon","Preventable Hospitalization Rate"]]

# %%
params = {
    "radius": 10000,
    "types": "meal_takeaway",
    "key": gkey
}

for index, row in places_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        places_df.loc[index, "Take Away Food"] = name_address["results"][0]["name"]
        print(f"Closest Fast Food is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
places_df.head()
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Closest Fast Food is Subway.
# Closest Fast Food is Subway.
# Missing field/result... skipping.
# Closest Fast Food is Subway.
# Closest Fast Food is Subway.
# Missing field/result... skipping.
# Closest Fast Food is Subway.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Fast Food is Subway.
# Missing field/result... skipping.
# Closest Fast Food is Subway.
# Missing field/result... skipping.
# Closest Fast Food is Subway.
# Missing field/result... skipping.
# Closest Fast Food is Subway.
# Closest Fast Food is Subway.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Fast Food is Papa Murphy's | Take 'N' Bake Pizza.
# Closest Fast Food is Beau Jo's Idaho Springs.
# Closest Fast Food is Riverside Pizza.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Fast Food is BluTaco.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Fast Food is Subway.
# Closest Fast Food is Subway.
# Closest Fast Food is Moose Drop Inn.
# Closest Fast Food is Subway.
# Missing field/result... skipping.
#            State      County Code    Lat    Lon  \
# 0  West Virginia       Mingo   WV  37.53 -81.85
# 1       Kentucky      Monroe   KY  36.72 -85.96
# 2       Oklahoma      Harmon   OK  34.66 -99.77
# 3  West Virginia       Logan   WV  37.86 -81.83
# 4       Kentucky  Crittenden   KY  37.27 -88.08
#
#    Preventable Hospitalization Rate Take Away Food
# 0                           16802.0            NaN
# 1                           15420.0            NaN
# 2                           14776.0            NaN
# 3                           14383.0         Subway
# 4                           13912.0         Subway

# %%
params = {
    "radius": 10000,
    "types": "restaurant",
    "key": gkey
}
for index, row in places_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        places_df.loc[index, "Restaurant Name"] = name_address["results"][0]["name"]
        print(f"Closest Restaurant is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
places_df.head()
# Out:
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Closest Restaurant is Justonian Restaurant.
# Closest Restaurant is Nannie Jo's Restaurant.
# Missing field/result... skipping.
# Closest Restaurant is Subway.
# Closest Restaurant is Subway.
# Closest Restaurant is The Food Shack.
# Closest Restaurant is Subway.
# Closest Restaurant is Subway.
# Missing field/result... skipping.
# Closest Restaurant is Subway.
# Closest Restaurant is Cave-In-Rock State Park Restaurant.
# Missing field/result... skipping.
# Closest Restaurant is Subway.
# Closest Restaurant is Bella's Cafe.
# Closest Restaurant is Subway.
# Missing field/result... skipping.
# Closest Restaurant is El Azul Grande.
# Closest Restaurant is Patton's Patio.
# Closest Restaurant is Subway.
# Closest Restaurant is Subway.
# Closest Restaurant is El Vaquero Restaurant.
# Closest Restaurant is The Galley & Pub.
# Missing field/result... skipping.
# Closest Restaurant is Taggart's Grill.
# Closest Restaurant is Yesterday’s Cafe.
# Closest Restaurant is Papa Murphy's | Take 'N' Bake Pizza.
# Closest Restaurant is Tommyknocker Brewery & Pub.
# Closest Restaurant is Country Skillet.
# Closest Restaurant is Catkin Cafe.
# Missing field/result... skipping.
# Closest Restaurant is Adventures Resort- Bar, grill, and campground.
# Closest Restaurant is Ridge Inn.
# Closest Restaurant is Aladdin Cafe.
# Missing field/result... skipping.
# Closest Restaurant is The Glen Eden Restaurant.
# Closest Restaurant is Subway.
# Closest Restaurant is Subway.
# Closest Restaurant is Moose Drop Inn.
# Closest Restaurant is Walnut Creek Amish Flea Market.
# Missing field/result... skipping.
#            State      County Code    Lat    Lon  \
# 0  West Virginia       Mingo   WV  37.53 -81.85
# 1       Kentucky      Monroe   KY  36.72 -85.96
# 2       Oklahoma      Harmon   OK  34.66 -99.77
# 3  West Virginia       Logan   WV  37.86 -81.83
# 4       Kentucky  Crittenden   KY  37.27 -88.08
#
#    Preventable Hospitalization Rate Take Away Food         Restaurant Name
# 0                           16802.0            NaN    Justonian Restaurant
# 1                           15420.0            NaN  Nannie Jo's Restaurant
# 2                           14776.0            NaN                     NaN
# 3                           14383.0         Subway                  Subway
# 4                           13912.0         Subway                  Subway

# %%
#Nearby Hospitals
params = {
    "radius": 10000,
    "types": "hospital",
    "key": gkey
}
for index, row in places_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
   
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        places_df.loc[index, "Hospital"] = name_address["results"][0]["name"]
        print(f"Closest Hospital is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
places_df.head()
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Closest Hospital is Medical & Surgical Center, Morningside Drive.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Hospital is Harlan ARH Hospital.
# Missing field/result... skipping.
# Closest Hospital is Lifeline Health Care of Cumberland.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Hospital is Evergreen Medical Center.
# Missing field/result... skipping.
# Closest Hospital is Lifeline Health Care of Clinton.
# Missing field/result... skipping.
# Closest Hospital is Highlands ARH Regional Medical Center.
# Missing field/result... skipping.
# Closest Hospital is John Ed Chambers Memorial Hospital.
# Closest Hospital is Perry Community Hospital.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Hospital is Saint Alphonsus Medical Group Diabetes Care and Education.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Hospital is DaVita Four Rivers Dialysis Center.
# Missing field/result... skipping.
# Closest Hospital is New Bedford Care Center.
# Missing field/result... skipping.
#            State      County Code    Lat    Lon  \
# 0  West Virginia       Mingo   WV  37.53 -81.85
# 1       Kentucky      Monroe   KY  36.72 -85.96
# 2       Oklahoma      Harmon   OK  34.66 -99.77
# 3  West Virginia       Logan   WV  37.86 -81.83
# 4       Kentucky  Crittenden   KY  37.27 -88.08
#
#    Preventable Hospitalization Rate Take Away Food         Restaurant Name  \
# 0                           16802.0            NaN    Justonian Restaurant
# 1                           15420.0            NaN  Nannie Jo's Restaurant
# 2                           14776.0            NaN                     NaN
# 3                           14383.0         Subway                  Subway
# 4                           13912.0         Subway                  Subway
#
#                                        Hospital
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4  Medical & Surgical Center, Morningside Drive

# %%
#Nearby Parks
params = {
    "radius": 10000,
    "types": "park",
    "key": gkey
}
for index, row in places_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
   
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        places_df.loc[index, "Parks"] = name_address["results"][0]["name"]
        print(f"Closest Park is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
places_df.head()
# Out:
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Closest Park is Ben Creek Park.
# Closest Park is Barefoot Republic Camp.
# Missing field/result... skipping.
# Closest Park is Rockhouse Lake Park.
# Closest Park is War Eagle RV Park.
# Closest Park is Alexander park.
# Closest Park is Tug Valley Little League.
# Closest Park is South Evarts RV Park.
# Closest Park is Larry Warren's RV Park.
# Closest Park is Lucas Hollow.
# Closest Park is Cave In Rock State Park.
# Closest Park is Harlan County Campground & RV.
# Closest Park is Evergreen-Conecuh County Veterans Memorial.
# Missing field/result... skipping.
# Closest Park is Mountain View Recreational.
# Missing field/result... skipping.
# Closest Park is Jenny Wiley State Resort Park.
# Closest Park is National Park Services.
# Closest Park is Belleville City Park.
# Closest Park is Perry County Shooting Range.
# Closest Park is Gruver City Park.
# Closest Park is Dosewallips State Park.
# Closest Park is Myrtle Falls Trail.
# Closest Park is Croydon City Park.
# Closest Park is Dell Park.
# Closest Park is Cedar Acres Park.
# Closest Park is Lawson Adventure Park & Resort.
# Closest Park is At the Ridge.
# Closest Park is Dot Rock State Park.
# Closest Park is Rancho Del Rio.
# Closest Park is Josie Creek County Park.
# Closest Park is The Spotted Horse Ranch.
# Closest Park is JC Stage Stop B&B.
# Missing field/result... skipping.
# Closest Park is Seedhouse Campground.
# Closest Park is US Forest Service.
# Closest Park is Kiwanis Park.
# Closest Park is Van Riper State Park.
# Closest Park is Ohio Northern University Nature Center.
# Missing field/result... skipping.
#            State      County Code    Lat    Lon  \
# 0  West Virginia       Mingo   WV  37.53 -81.85
# 1       Kentucky      Monroe   KY  36.72 -85.96
# 2       Oklahoma      Harmon   OK  34.66 -99.77
# 3  West Virginia       Logan   WV  37.86 -81.83
# 4       Kentucky  Crittenden   KY  37.27 -88.08
#
#    Preventable Hospitalization Rate Take Away Food         Restaurant Name  \
# 0                           16802.0            NaN    Justonian Restaurant
# 1                           15420.0            NaN  Nannie Jo's Restaurant
# 2                           14776.0            NaN                     NaN
# 3                           14383.0         Subway                  Subway
# 4                           13912.0         Subway                  Subway
#
#                                        Hospital                   Parks
# 0                                           NaN          Ben Creek Park
# 1                                           NaN  Barefoot Republic Camp
# 2                                           NaN                     NaN
# 3                                           NaN     Rockhouse Lake Park
# 4  Medical & Surgical Center, Morningside Drive       War Eagle RV Park

# %%
#Nearby Gyms
params = {
    "radius": 10000,
    "types": "gym",
    "key": gkey
}
for index, row in places_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
   
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        places_df.loc[index, "Gyms"] = name_address["results"][0]["name"]
        print(f"Closest Gym is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
places_df.head()
# Out:
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Closest Gym is Larry Joe Harless Community Center.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Gym is Addison Gym.
# Missing field/result... skipping.
# Closest Gym is Core Fitness 24/7 Health.
# Missing field/result... skipping.
# Closest Gym is Dog House Gym.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Gym is Club Fit Studio.
# Missing field/result... skipping.
# Closest Gym is Ted Lyons Gymnasium.
# Closest Gym is The Gym & Fitness Center.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Gym is Club 24 Baker City.
# Closest Gym is Two Brothers Deli.
# Closest Gym is Next Level Fitness.
# Closest Gym is Lopez Pilates.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Gym is Newcastle Lodge & Convention Center.
# Closest Gym is Grizzly Yoga Center.
# Missing field/result... skipping.
# Closest Gym is Oasis youth center.
# Missing field/result... skipping.
#            State      County Code    Lat    Lon  \
# 0  West Virginia       Mingo   WV  37.53 -81.85
# 1       Kentucky      Monroe   KY  36.72 -85.96
# 2       Oklahoma      Harmon   OK  34.66 -99.77
# 3  West Virginia       Logan   WV  37.86 -81.83
# 4       Kentucky  Crittenden   KY  37.27 -88.08
#
#    Preventable Hospitalization Rate Take Away Food         Restaurant Name  \
# 0                           16802.0            NaN    Justonian Restaurant
# 1                           15420.0            NaN  Nannie Jo's Restaurant
# 2                           14776.0            NaN                     NaN
# 3                           14383.0         Subway                  Subway
# 4                           13912.0         Subway                  Subway
#
#                                        Hospital                   Parks  \
# 0                                           NaN          Ben Creek Park
# 1                                           NaN  Barefoot Republic Camp
# 2                                           NaN                     NaN
# 3                                           NaN     Rockhouse Lake Park
# 4  Medical & Surgical Center, Morningside Drive       War Eagle RV Park
#
#                                  Gyms
# 0  Larry Joe Harless Community Center
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN

# %%
drops=places_df.dropna()
drops
# Out:
#         State      County Code    Lat     Lon  \
# 7    Kentucky      Harlan   KY  36.83  -83.25
# 9    Kentucky  Cumberland   KY  36.79  -85.36
# 16   Kentucky       Floyd   KY  37.74  -82.79
# 18   Arkansas        Yell   AR  35.09  -93.44
# 19  Tennessee       Perry   TN  35.61  -87.84
# 25     Oregon       Baker   OR  44.81 -117.74
# 36      Idaho     Payette   ID  43.96 -116.91
# 38       Ohio      Holmes   OH  40.44  -81.70
#
#     Preventable Hospitalization Rate                       Take Away Food  \
# 7                            13164.0                               Subway
# 9                            12534.0                               Subway
# 16                           11617.0                               Subway
# 18                           11211.0                               Subway
# 19                           10989.0                               Subway
# 25                             926.0  Papa Murphy's | Take 'N' Bake Pizza
# 36                            1387.0                               Subway
# 38                            1414.0                               Subway
#
#                         Restaurant Name  \
# 7                                Subway
# 9                                Subway
# 16                       El Azul Grande
# 18                               Subway
# 19                               Subway
# 25  Papa Murphy's | Take 'N' Bake Pizza
# 36                               Subway
# 38       Walnut Creek Amish Flea Market
#
#                                              Hospital  \
# 7                                 Harlan ARH Hospital
# 9                  Lifeline Health Care of Cumberland
# 16              Highlands ARH Regional Medical Center
# 18                 John Ed Chambers Memorial Hospital
# 19                           Perry Community Hospital
# 25  Saint Alphonsus Medical Group Diabetes Care an...
# 36                 DaVita Four Rivers Dialysis Center
# 38                            New Bedford Care Center
#
#                                      Parks                      Gyms
# 7                     South Evarts RV Park  Core Fitness 24/7 Health
# 9                             Lucas Hollow             Dog House Gym
# 16           Jenny Wiley State Resort Park           Club Fit Studio
# 18                    Belleville City Park       Ted Lyons Gymnasium
# 19             Perry County Shooting Range  The Gym & Fitness Center
# 25                        Cedar Acres Park        Club 24 Baker City
# 36                            Kiwanis Park       Grizzly Yoga Center
# 38  Ohio Northern University Nature Center        Oasis youth center
