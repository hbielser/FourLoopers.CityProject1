# %%
#dependencies
import requests
import json
import pandas as pd
import numpy as np

# Google developer API key
#from config import gkey
gkey = "AIzaSyAvuOCIVC1906HxDHTcVh8kpYL4QVPV2bQ"

# %%
county_geo = "../../Resources/StudyData.csv"
county_df = pd.read_csv(county_geo)
county_df.head()
# Out:
#    Unnamed: 0   FIPS          State      County  \
# 0           0  54059  West Virginia       Mingo
# 1           1  21171       Kentucky      Monroe
# 2           2  40057       Oklahoma      Harmon
# 3           3  54045  West Virginia       Logan
# 4           4  21055       Kentucky  Crittenden
#
#    Years of Potential Life Lost Rate  % Fair or Poor Health  \
# 0                            14564.0                     28
# 1                            12131.0                     24
# 2                            14123.0                     22
# 3                            15459.0                     26
# 4                            10623.0                     22
#
#    Average Number of Physically Unhealthy Days  \
# 0                                          6.3
# 1                                          5.2
# 2                                          4.4
# 3                                          5.8
# 4                                          5.0
#
# ...

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#meal_takeaway_df =[]
hospitals = []

#for index, row in county_df.iterrows():
    #lat = row["Lat"]
    #lng = row["Lon"]
    #coordinates = f'{lat}'
locations = county_df[["Lat","Lon"]]
target_type = "meal_takeaway"
radius = 5000
    
params = {"location":locations,
            "rankby": radius,
             "type": target_type,
               "key": gkey}

response = requests.get(base_url, params=params).json()
results = response['results']
print(response)
    #try:
        #meal_takeaway_df.append[index, "name"]=results[0]["name"]
    #except:
# Out:
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}

# %%
county_df["Restaurant Name"] = ""
county_df["Take Away Food"] = ""
meal_takeaway_df = county_df[["State", "County", "Code", "Lat" , "Lon"]]

# %%
params = {
    "radius": 10000,
    "types": "meal_takeaway",
    "key": gkey
}
# Use the lat/lng we recovered to identify hotels
for index, row in meal_takeaway_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        meal_takeaway_df.loc[index, "Take Away Food"] = name_address["results"][0]["name"]
        #county_df.loc[index, "Hotel Address"] = name_address["results"][0]["vicinity"]
        print(f"Closest Fast Food is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
meal_takeaway_df.head()
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Closest Fast Food is Subway.
# ...

# %%
#meal_takeaway_df.loc[meal_takeaway_df["Restaurant Name"]!= "NaN"]
#no_hotel = meal_takeaway_df[meal_takeaway_df["Restaurant Name"] == " NaN"].index
no_restaurant=meal_takeaway_df.dropna()
no_restaurant
# Out:
#              State        County Code    Lat     Lon  \
# 3    West Virginia         Logan   WV  37.86  -81.83
# 4         Kentucky    Crittenden   KY  37.27  -88.08
# 6         Kentucky        Martin   KY  37.83  -82.43
# 7         Kentucky        Harlan   KY  36.83  -83.25
# 9         Kentucky    Cumberland   KY  36.79  -85.36
# 12         Alabama       Conecuh   AL  31.43  -86.95
# 14        Kentucky       Clinton   KY  36.69  -85.13
# 16        Kentucky         Floyd   KY  37.74  -82.79
# 18        Arkansas          Yell   AR  35.09  -93.44
# 19       Tennessee         Perry   TN  35.61  -87.84
# 25          Oregon         Baker   OR  44.81 -117.74
# 26        Colorado   Clear Creek   CO  39.78 -105.60
# 27  North Carolina  Transylvania   NC  35.22  -82.87
# 31            Ohio          Ross   OH  39.46  -82.74
# 35         Wyoming        Weston   WY  43.84 -104.21
# 36           Idaho       Payette   ID  43.96 -116.91
# 37        Michigan        Baraga   MI  46.53  -88.11
# ...

# %%
params = {
    "radius": 10000,
    "types": "restaurant",
    "key": gkey
}
# Use the lat/lng we recovered to identify hotels
for index, row in meal_takeaway_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        meal_takeaway_df.loc[index, "Restaurant Name"] = name_address["results"][0]["name"]
        #county_df.loc[index, "Hotel Address"] = name_address["results"][0]["vicinity"]
        print(f"Closest Restaurant is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
meal_takeaway_df.head()
# Out:
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Closest Restaurant is Justonian Restaurant.
# Closest Restaurant is Nannie Jo's Restaurant.
# Missing field/result... skipping.
# Closest Restaurant is Subway.
# Closest Restaurant is Subway.
# Closest Restaurant is The Food Shack.
# Closest Restaurant is Subway.
# Closest Restaurant is Subway.
# Missing field/result... skipping.
# Closest Restaurant is Subway.
# Closest Restaurant is Cave-In-Rock State Park Restaurant.
# Missing field/result... skipping.
# Closest Restaurant is Subway.
# Closest Restaurant is Bella's Cafe.
# Closest Restaurant is Subway.
# ...

# %%
no_drop=meal_takeaway_df.dropna()
no_drop
# Out:
#              State        County Code    Lat     Lon  \
# 3    West Virginia         Logan   WV  37.86  -81.83
# 4         Kentucky    Crittenden   KY  37.27  -88.08
# 6         Kentucky        Martin   KY  37.83  -82.43
# 7         Kentucky        Harlan   KY  36.83  -83.25
# 9         Kentucky    Cumberland   KY  36.79  -85.36
# 12         Alabama       Conecuh   AL  31.43  -86.95
# 14        Kentucky       Clinton   KY  36.69  -85.13
# 16        Kentucky         Floyd   KY  37.74  -82.79
# 18        Arkansas          Yell   AR  35.09  -93.44
# 19       Tennessee         Perry   TN  35.61  -87.84
# 25          Oregon         Baker   OR  44.81 -117.74
# 26        Colorado   Clear Creek   CO  39.78 -105.60
# 27  North Carolina  Transylvania   NC  35.22  -82.87
# 31            Ohio          Ross   OH  39.46  -82.74
# 35         Wyoming        Weston   WY  43.84 -104.21
# 36           Idaho       Payette   ID  43.96 -116.91
# 37        Michigan        Baraga   MI  46.53  -88.11
# ...

# %%
len(no_drop)
# Out:
# 18

# %%
#Nearby Hospitals
    hospital_locate = row[]
    params[]

# %%
#Nearby Parks

# %%
# Store 'Lat' and 'Lng' into  locations
#locations = census_data_complete[["Lat", "Lng"]].astype(float)
#locations = county_df[["Lat", "Lon"]].astype(float)
