# %%
#dependencies
import requests
import json
import pandas as pd
import numpy as np
import gmaps


# Google developer API key
#from config import gkey
gkey = "AIzaSyA4RYdQ1nxoMTIW854C7wvVJMf0Qz5qjNk"

# %%
county_geo = "../../Resources/PoorHealth_StudyData.csv"
county_df = pd.read_csv(county_geo)
county_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   FIPS        State     County  \
# 0           0          2403  48507        Texas     Zavala
# 1           1          2368  48427        Texas      Starr
# 2           2          1281  28051  Mississippi     Holmes
# 3           3          1268  28021  Mississippi  Claiborne
# 4           4          1286  28063  Mississippi  Jefferson
#
#    Years of Potential Life Lost Rate  % Fair or Poor Health  \
# 0                             8926.0                     41
# 1                             6697.0                     39
# 2                            14318.0                     38
# 3                            14651.0                     37
# 4                            15171.0                     37
#
#    Average Number of Physically Unhealthy Days  \
# 0                                          5.7
# 1                                          5.5
# 2                                          6.1
# 3                                          6.1
# ...

# %%
#gkey = "AIzaSyDZ0NStSeomJLtlfN4UE3YMfDXWlBpi8A0"
# 39.0473° N, 95.6752° W
# 39.0375° N, 95.7680°
#base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#drugstore , gas_station,pharmacy
#params = {
    #"location": "39.0375,-95.7680",  
    #"rankby": "distance",
    #"type": "supermarket",
    #"key": gkey,
    #"radius": "50000"
#}
#food = []
#response = requests.get(base_url, params=params).json()
# extract results
#results = response['results']
#for r in results:
    #food.append(r)
    #params['page_token'] = response['next_page_token']
    #response = requests.get(base_url, params=params).json()
# extract results
    #results = response['results']
#for r in results:
    #food.append(r)
    #params['page_token'] = response['next_page_token']
    #response = requests.get(base_url, params=params).json()
# extract results
    #results = response['results']
#for r in results:
    #food.append(r)
    #token = response['next_page_token']
#print(food.__len__())
#csv_columns = ['name', 'opening_hours', 'price_level', 'id', 'scope', 'rating', 'types', 'plus_code',
               #'user_ratings_total', 'vicinity', 'place_id', 'business_status', 'geometry', 'photos', 'reference', 'icon']
#try:
    #with open("food.csv", 'w') as csvfile:
        #writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        #writer.writeheader()
        #for data in stores:
            #writer.writerow(data)
#except IOError:
 #   print("I/O error")

# %%
#county_df["Restaurant Name"] = ""
#county_df["Take Away Food"] = ""
#county_df["Hospital"] = ""
county_df["Parks"]=""
county_df["Gyms"]=""
places_df = county_df[["State", "County", "Code", "Lat" , "Lon","% Fair or Poor Health"]]

# %%
params = {
    "radius": 10000,
    "types": "meal_takeaway",
    "key": gkey
}

for index, row in places_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        places_df.loc[index, "Take Away Food"] = name_address["results"][0]["name"]
        print(f"Closest Fast Food is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
places_df.head()
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# ...

# %%
params = {
    "radius": 10000,
    "types": "restaurant",
    "key": gkey
}
for index, row in places_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        places_df.loc[index, "Restaurant Name"] = name_address["results"][0]["name"]
        print(f"Closest Restaurant is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
places_df.head()
# Out:
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Closest Restaurant is Desi's Restaurant.
# Closest Restaurant is BOONEBUCKS.
# Missing field/result... skipping.
# ...

# %%
#Nearby Hospitals
params = {
    "radius": 10000,
    "types": "hospital",
    "key": gkey
}
for index, row in places_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
   
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        places_df.loc[index, "Hospital"] = name_address["results"][0]["name"]
        print(f"Closest Hospital is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
places_df.head()
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# ...

# %%
#Nearby Parks
params = {
    "radius": 10000,
    "types": "park",
    "key": gkey
}
for index, row in places_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
   
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        places_df.loc[index, "Parks"] = name_address["results"][0]["name"]
        print(f"Closest Park is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
places_df.head()
# Out:
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/brittanyouellette/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Closest Park is H4 Ranches.
# Missing field/result... skipping.
# Closest Park is Mathews Brake National Wildlife Refuge.
# ...

# %%
#Nearby Gyms
params = {
    "radius": 10000,
    "types": "gym",
    "key": gkey
}
for index, row in places_df.iterrows():
    
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lon"]
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
   
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        places_df.loc[index, "Gyms"] = name_address["results"][0]["name"]
        #places_df.loc[index, "Gym Lat"] = results[0]['geometry']['location']['lat']
        #places_df.loc[index, "Gym Lng"] = results[0]['geometry']['location']['lng']
        print(f"Closest Gym is {name_address['results'][0]['name']}.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
places_df.head()
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Gym is Champion Fit.
# Closest Gym is Snap Fitness Clarksdale.
# Closest Gym is Gym.
# Closest Gym is Saint George Fitness.
# Closest Gym is Canizales Boxing Gym.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Gym is Brandon’s spirit factory.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Closest Gym is Castle Rock Community Rec Center.
# Closest Gym is 24 Hour Fitness.
# Missing field/result... skipping.
# Closest Gym is Fishmoon Yoga.
# Closest Gym is ETrain Sports Training Shakopee.
# Closest Gym is Woodbury YMCA.
# Closest Gym is Planet Fitness.
# ...

# %%
drops=places_df.dropna()
drops
# Out:
#             State      County Code    Lat     Lon  % Fair or Poor Health  \
# 9         Alabama       Perry   AL  32.63  -87.31                     35
# 10    Mississippi     Coahoma   MS  34.20  -90.57                     35
# 11          Texas    Maverick   TX  28.70 -100.49                     35
# 13          Texas        Webb   TX  27.53  -99.48                     35
# 16       Kentucky    McCreary   KY  36.74  -84.48                     34
# 20       Colorado     Douglas   CO  39.37 -104.85                      8
# 21       Colorado   Jefferson   CO  39.82 -105.10                      9
# 24      Minnesota      Carver   MN  44.76  -93.62                      9
# 25      Minnesota  Washington   MN  44.90  -92.81                      9
# 26  New Hampshire  Rockingham   NH  43.00  -71.34                      9
# 27   South Dakota     Lincoln   SD  43.30  -96.58                      9
# 28       Colorado  Broomfield   CO  39.94 -105.06                     10
# ...

# %%
len(drops)
# Out:
# 21

# %%
n_cities = 20
top_n = places_df.nlargest(n_cities, ['% Fair or Poor Health'])
bottom_n = places_df.nsmallest(n_cities, ['% Fair or Poor Health'])
top_n
# Out:
#           State     County Code    Lat     Lon  % Fair or Poor Health  \
# 0         Texas     Zavala   TX  28.94  -99.61                     41
# 1         Texas      Starr   TX  26.64  -98.40                     39
# 2   Mississippi     Holmes   MS  33.32  -90.23                     38
# 3   Mississippi  Claiborne   MS  32.02  -90.80                     37
# 4   Mississippi  Jefferson   MS  31.71  -91.06                     37
# 5         Texas    Willacy   TX  26.53  -97.88                     37
# 6   Mississippi  Humphreys   MS  33.26  -90.59                     36
# 7   Mississippi    Quitman   MS  34.26  -90.35                     36
# 8         Texas     Zapata   TX  27.19  -99.32                     36
# 9       Alabama      Perry   AL  32.63  -87.31                     35
# 10  Mississippi    Coahoma   MS  34.20  -90.57                     35
# 11        Texas   Maverick   TX  28.70 -100.49                     35
# ...

# %%
locations = places_df[["Lat", "Lon"]].astype(float)
#markers=gmaps.marker_layer(locations)

symbol_layer = gmaps.symbol_layer(locations, fill_color='blue', stroke_color='blue', scale=2)
    #info_box_content=[f"Gyms amount: {bank}" for bank in bank_rate]

fig = gmaps.figure()
fig.add_layer(symbol_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#store humidity as float
#https://datatofish.com/convert-string-to-float-dataframe/
places_df["% Fair or Poor Health"] = places_df["% Fair or Poor Health"].astype(float)
#fig = gmaps.figure(center = (20,0), zoom_level = 2.2)
heat_layer = gmaps.heatmap_layer(locations, weights=places_df['% Fair or Poor Health'], 
                                 dissipating=False, max_intensity=250, point_radius=2)
fig.add_layer(heat_layer)
fig
# Out:
# <ipython-input-90-bc7257e0e959>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   places_df["% Fair or Poor Health"] = places_df["% Fair or Poor Health"].astype(float)
# Figure(layout=FigureLayout(height='420px'))

# %%
#import gmaps.datasets
#gmaps.configure(gkey)
#places_df = gmaps.datasets.load_dataset_as_df('starbucks_kfc_uk')
#starbucks_df = df[df['chain_name'] == 'starbucks']
#starbucks_df = starbucks_df[['latitude', 'longitude']]
#kfc_df = df[df['chain_name'] == 'kfc']
#kfc_df = kfc_df[['latitude', 'longitude']]
top_locations = top_n[["Lat", "Lon"]].astype(float)
bottom_locations= bottom_n[["Lat", "Lon"]].astype(float)
top_layer = gmaps.symbol_layer(
    top_locations, fill_color='rgba(200, 0, 0, 0.4)',
    stroke_color='rgba(200, 0, 0, 0.4)', scale=5
)
bottom_layer = gmaps.symbol_layer(
    bottom_locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 150, 0, 0.4)', scale=5
)
fig = gmaps.figure()
fig.add_layer(top_layer)
fig.add_layer(bottom_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
